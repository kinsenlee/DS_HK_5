# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt
from ggplot import *

# %%
air = pd.read_csv('../data/airquality.csv')

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1     41      190   7.4    67      5    1
# 1           2     36      118   8.0    72      5    2
# 2           3     12      149  12.6    74      5    3
# 3           4     18      313  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
air.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind        Temp       Month  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean    77.000000   42.129310  185.931507    9.957516   77.882353    6.993464
# std     44.311398   32.987885   90.058422    3.523001    9.465270    1.416522
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     39.000000   18.000000  115.750000    7.400000   72.000000    6.000000
# 50%     77.000000   31.500000  205.000000    9.700000   79.000000    7.000000
# 75%    115.000000   63.250000  258.750000   11.500000   85.000000    8.000000
# max    153.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day
# count  153.000000
# mean    15.803922
# std      8.864520
# min      1.000000
# 25%      8.000000
# 50%     16.000000
# 75%     23.000000
# max     31.000000

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 7 columns):
# Unnamed: 0    153 non-null int64
# Ozone         116 non-null float64
# Solar.R       146 non-null float64
# Wind          153 non-null float64
# Temp          153 non-null int64
# Month         153 non-null int64
# Day           153 non-null int64
# dtypes: float64(3), int64(4)

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(air, alpha=0.2, figsize=(15, 15), diagonal='kde')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7f3255415210>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x7f3253192490>]], dtype=object)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=8.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
air.groupby(['Month']).count()
# --> it is mainly missing data in June, while minimal data missing in other months
# Therefore,
# Out:
#        Unnamed: 0  Ozone  Solar.R  Wind  Temp  Day
# Month
# 5              31     26       27    31    31   31
# 6              30      9       30    30    30   30
# 7              31     26       31    31    31   31
# 8              31     26       28    31    31   31
# 9              30     29       30    30    30   30

# %%
air.groupby(['Month']).agg([np.min, np.max, np.mean])
# Out:
#        Unnamed: 0               Ozone                   Solar.R        \
#              amin  amax   mean   amin  amax       mean     amin  amax
# Month
# 5               1    31   16.0      1   115  23.615385        8   334
# 6              32    61   46.5     12    71  29.444444       31   332
# 7              62    92   77.0      7   135  59.115385        7   314
# 8              93   123  108.0      9   168  59.961538       24   273
# 9             124   153  138.5      7    96  31.448276       14   259
#
#                    Wind                   Temp                    Day        \
#              mean  amin  amax       mean  amin  amax       mean  amin  amax
# Month
# 5      181.296296   5.7  20.1  11.622581    56    81  65.548387     1    31
# 6      190.166667   1.7  20.7  10.266667    65    93  79.100000     1    30
# 7      216.483871   4.1  14.9   8.941935    73    92  83.903226     1    31
# 8      171.857143   2.3  15.5   8.793548    72    97  83.967742     1    31
# ...

# %%
for col in air.columns:
    print 'Summary statistics for ' + str(col)
    print 'max = ' + str(air[col].max())
    print 'min = ' + str(air[col].min())
    print 'mean = ' + str(air[col].mean())
# Out:
# Summary statistics for Unnamed: 0
# max = 153
# min = 1
# mean = 77.0
# Summary statistics for Ozone
# max = 168.0
# min = 1.0
# mean = 42.1293103448
# Summary statistics for Solar.R
# max = 334.0
# min = 7.0
# mean = 185.931506849
# Summary statistics for Wind
# max = 20.7
# min = 1.7
# mean = 9.95751633987
# Summary statistics for Temp
# max = 97
# min = 56
# mean = 77.8823529412
# Summary statistics for Month
# max = 9
# min = 5
# mean = 6.99346405229
# Summary statistics for Day
# max = 31
# min = 1
# mean = 15.8039215686

# %%
sns.lmplot("Month", "Solar.R", air, x_estimator=np.mean)

# %%
sns.lmplot("Month", "Wind", air, x_estimator=np.mean)

# %%
sns.lmplot("Month", "Temp", air, x_estimator=np.mean)

#

# %%
sns.lmplot("Month", "Ozone", air, x_estimator=np.mean)

# %%
sns.lmplot("Solar.R", "Ozone", air)

# higher the Solar.R, higher the Ozone

# %%
sns.lmplot("Temp", "Ozone", air)

# higher the temperature, higher the ozone

# %%
from statsmodels.formula.api import ols

results = ols('Ozone ~ Temp', air).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Ozone   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     108.5
# Date:                Fri, 20 Mar 2015   Prob (F-statistic):           2.93e-18
# Time:                        18:22:37   Log-Likelihood:                -530.85
# No. Observations:                 116   AIC:                             1066.
# Df Residuals:                     114   BIC:                             1071.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -146.9955     18.287     -8.038      0.000      -183.222  -110.769
# ...

# %%
sns.lmplot("Wind", "Ozone", air)

# higher the wind, lower the ozone

# %%
sns.lmplot("Solar.R", "Wind", air)

# Wind is random regardless of the change in solar.R

# %%
sns.lmplot("Solar.R", "Temp", air)

# higher solar.R, higher temp

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1     41      190   7.4    67      5    1
# 1           2     36      118   8.0    72      5    2
# 2           3     12      149  12.6    74      5    3
# 3           4     18      313  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
cols = air.columns.tolist()
cols
# Out:
# ['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day']

# %%
colsNew = cols
colsNew.remove('Day')
colsNew.remove('Unnamed: 0')
colsNew
# Out:
# ['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month']

# %%
for x in cols:
    for y in cols:
        if x == 'Month':
            sns.lmplot(x, y, air, x_estimator=np.mean)
        elif x !='Unnamed: 0' and x!=y:
            sns.lmplot(x, y, air)

# %%
# Answer to classwork questions:
# 1. 153 data points
# 2. describe() tells me the sample population, while info() tells me the data type mainly)
# 3. see In[25]
# 4. Pandas ignore the NA values by default
# 5. (1) pad with mean value of each month, or (2) pad with random values from population of the month, or 
#    (3) pad with random values from overall population (4) pad with overall mean values
# 6. Visual ways: (1) desity graph of each variable (2) linear relationship of each combination of 2 variables
# 7. Relationship
#    Density of Ozone, Solor.R, Wind, Temp --> more or less normally distributed, with mean shifted differently
#    Linear Plots against Month: 
#       +ve correlated: Temp, Ozone; -ve correlated: Wind, Solar.R
#    Plots against Temp:
#       +ve correlated: Solar.R, Ozone; -ve correlated: Wind,
#    Plots against Wind:
#       -ve correlated: Temp, Ozone; random: solar.R
#    Plots against Solar.R:
#       +ve correlated: Temp, Ozone; random: wind
#    Plots against OZone:
#       +ve correlated: Temp, Solar.R; -ve correlated: wind
#
